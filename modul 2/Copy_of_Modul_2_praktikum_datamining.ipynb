# %% [markdown]
# <a href="https://colab.research.google.com/github/H4rfu1/data-mining-dasar/blob/main/modul%202/Copy_of_Modul_2_praktikum_datamining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # modul kelas

# %% [markdown]
# ## Kode 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# 1.   Jelaskan fungsi dari library matplotlib. Jelaskan tentang plyplot
# - Matplotlib adalah  library Python 2D yang dapat menghasilkan plot dengan kualitas tinggi dalam berbagai format dan dapat digunakan di banyak platform. Matplotlib juga dapat digunakan untuk memvisualisasikan data secara 2D maupun 3D di dalam Python dan menghasilkan gambar berkualitas dalam berbagai format. Matplotlib dapat digunakan sebagai pembuat grafik dalam berbagai platform, seperti Python dan Jupyter. Grafik yang dapat dibuat beragam, seperti grafik garis, batang, lingkaran, histogram, dsb.
# https://medium.com/@symdu31/visualisasi-data-menggunakan-python-dan-matplotlib-de271812b2fd
# - pyplot adalah

# %% [markdown]
# 2. Sebutkan koordinat yang akan digambar oleh kode baris 4 – 5
#
# - 0,0 dan 6,250

# %% [markdown]
# 3. Apa fungsi kode baris 6
#
# - menggabungkan koordinat

# %% [markdown]
# 4. Apa fungsi kode baris 7
#
# - melakukan visualisasi titik koordinat garis yang sudah digabungkan

# %% [markdown]
# 5. Gantilah baris 6 dengan plt.plot(xpoints, ypoints, 'o'). jelaskan apa yang terjadi

# %%
az = plt.plot(xpoints, ypoints,'o')
print(az.)

# %% [markdown]
# 6. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17, 11),(19,4),(20,20)  dengan garis

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
graph = plt.plot(xpoints, ypoints, 'o')
plt.show(graph)

# %% [markdown]
# 7. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20)  tanpa garis

# %%
xpoints = np.array([7,10,11,14,17,17,19])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ## Kode 2

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, color = 'r', ls = '--', linewidth = '5')
plt.show()

# %%
y1 = np.array([6, 1, 4, 6])
x1 = np.array(['a', 'b', 'c', 'd'])
y2 = np.array([0, 1, 2, 3])
x2 = np.array(['a', 'b', 'c', 'd'])
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %% [markdown]
# 1. Jelaskan fungsi dari baris 5. Jelaskan makna parameter ms, mec, mfc
# - ms tebal
# - mec enis titil
# - mfc marcerfacecoloor, warna color

# %% [markdown]
# 2. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) dengan marker star, ukuran marker 15, warna tepi marker biru, warna area dalam marker kuning

# %% [markdown]
# 3. Jelaskan fungsi baris 9. Jelaskan makna parameter color. Ls, linewidth
# - color warna line
# - ls line style
# - linewidth, besar line

# %% [markdown]
# 4. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) dengan garis warna kuning ukuran 5 dengan style garis penuh

# %% [markdown]
# 5. Jelaskan kode baris 12 – 17
# - sama melakukan visualisasi dua garis

# %% [markdown]
# 6. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20). Kemudian tambahkan koordinat yang posisinya 1 satuan di atas koordinat awal. Kemudian tambahkan koordinat yang posisinya 2 satuan di kanan koordinat awal.

# %% [markdown]
# ##Kode 3

# %%
import matplotlib.pyplot as plt
import numpy as np

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
font3 = {'family':'serif','color':'darkred','size':15}

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# %%
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.show()

# %%
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# 1. Jelaskan fungsi dari baris 7 – 12
# - buat variable nyimpan font

# %% [markdown]
# 2. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20). Beri keterangan sumbu X : nilai mendatar, sumbu Y : nilai vertikal, dan judul : latihan. Untuk judul dan sumbu Y  gunakan font 1. Untuk sumbu X gunakan font 2

# %% [markdown]
# 3. Jelaskan fungsi dari baris 18 – 22
# -

# %% [markdown]
# 4. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) di subplot 1. Koordinat yang posisinya 1 satuan di atas koordinat awal di subplot 2. Koordinat yang posisinya 1 satuan di atas koordinat awal di subplot 3.

# %% [markdown]
# ##Kode 4

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# 1. Jelaskan fungsi dari baris 4 – 12
# - buat scatter plot

# %% [markdown]
# 2. Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) dalam bentuk scatter plot. Dan koordinat yang posisinya 1 satuan di atas koordinat awal sebagai scatterplot yang berbeda.

# %% [markdown]
# # Modul latihan

# %% [markdown]
# ###1 Jelaskan makna dataset. Jelaskan pula makna data training dan data testing

# %% [markdown]
# ###2 Jelaskan proses penyusunan dataset

# %% [markdown]
# ###3 Jelaskan makna attribut dataset iris. Jelaskan pula makna kelas dataset iris

# %% [markdown]
# ###4 Masukkan dataset iris sebagai array 2D di numpy. Pisahkan setiap kelas di array yang berbeda : setosa, versicolor, virginica, dan unknown

# %%
# !wget https://docs.google.com/spreadsheets/d/1Y-N0XSrfpkCQ9GvskIf34MbMgWfD1jU9/gviz/tq?tqx=out:csv&sheet=iris
# !mv /content/tq?tqx=out:csv /content/iris.csv
# Out:
# --2021-03-13 03:18:12--  https://docs.google.com/spreadsheets/d/1Y-N0XSrfpkCQ9GvskIf34MbMgWfD1jU9/gviz/tq?tqx=out:csv
# Resolving docs.google.com (docs.google.com)... 108.177.119.102, 108.177.119.100, 108.177.119.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘tq?tqx=out:csv’
#
# tq?tqx=out:csv          [ <=>                ]   8.52K  --.-KB/s    in 0s
#
# 2021-03-13 03:18:12 (59.5 MB/s) - ‘tq?tqx=out:csv’ saved [8726]

# %%
# !head '/content/iris.csv'
# Out:
# "","","No","Petal_width","Petal_length","Sepal_width","Sepal_length","Species_name","",""
# "","","1","0.2","1.4","3.5","5.1"," Setosa","","[0.2,1.4,3.5,5.1]"
# "","","2","0.2","1.4","3","4.9"," Setosa","","[0.2,1.4,3,4.9]"
# "","","3","0.2","1.3","3.2","4.7"," Setosa","","[0.2,1.3,3.2,4.7]"
# "","","4","0.2","1.5","3.1","4.6"," Setosa","","[0.2,1.5,3.1,4.6]"
# "","","5","0.2","1.4","3.6","5"," Setosa","","[0.2,1.4,3.6,5]"
# "","","6","0.4","1.7","3.9","5.4"," Setosa","","[0.4,1.7,3.9,5.4]"
# "","","7","0.3","1.4","3.4","4.6"," Setosa","","[0.3,1.4,3.4,4.6]"
# "","","8","0.2","1.5","3.4","5"," Setosa","","[0.2,1.5,3.4,5]"
# "","","9","0.2","1.4","2.9","4.4"," Setosa","","[0.2,1.4,2.9,4.4]"

# %%
#import librari pandas
import numpy as np
import pandas as pd
#import dataset dari csv/excel menjadi pandas
df=pd.read_csv('/content/iris.csv', sep=',',header=None)
#ubah dataset dari pandas ke array numpy

dataset = df.to_numpy()
#menghilangkan kolom dan baris Nan/kosong
dataset = dataset[:,3:8]
print(dataset[:5])
# type(dataset)
# dfdataset = pd.DataFrame(dataset, columns = ['Petal_width','Petal_length','Sepal_width','Sepal_length','Species_name'])
# dfdataset
# Out:
# [['Petal_width' 'Petal_length' 'Sepal_width' 'Sepal_length'
#   'Species_name']
#  ['0.2' '1.4' '3.5' '5.1' ' Setosa']
#  ['0.2' '1.4' '3' '4.9' ' Setosa']
#  ['0.2' '1.3' '3.2' '4.7' ' Setosa']
#  ['0.2' '1.5' '3.1' '4.6' ' Setosa']]

# %%
#kelas setosa
setosa = np.array([isibaris[:4] for isibaris in dataset if isibaris[4] == ' Setosa'])
setosa = setosa.astype(np.float)
print(setosa[:5])
# Out:
# [[0.2 1.4 3.5 5.1]
#  [0.2 1.4 3.  4.9]
#  [0.2 1.3 3.2 4.7]
#  [0.2 1.5 3.1 4.6]
#  [0.2 1.4 3.6 5. ]]

# %%
#kelas versicolor
versicolor = np.array([isibaris[:4] for isibaris in dataset if isibaris[4] == ' Versicolor'])
versicolor = versicolor.astype(np.float)
print(versicolor[:5])
# Out:
# [[1.4 4.7 3.2 7. ]
#  [1.5 4.5 3.2 6.4]
#  [1.5 4.9 3.1 6.9]
#  [1.3 4.  2.3 5.5]
#  [1.5 4.6 2.8 6.5]]

# %%
#kelas virginica
virginica = np.array([isibaris[:4] for isibaris in dataset if isibaris[4] == ' Verginica'])
virginica = virginica.astype(np.float)
print(virginica[:5])
# Out:
# [[2.5 6.  3.3 6.3]
#  [1.9 5.1 2.7 5.8]
#  [2.1 5.9 3.  7.1]
#  [1.8 5.6 2.9 6.3]
#  [2.2 5.8 3.  6.5]]

# %%
#kelas unknown
unknown = np.array([isibaris[:4] for isibaris in dataset if isibaris[4] == 'unknown'])
unknown = unknown.astype(np.float)
print(unknown[:3])
# Out:
# [[0.3 1.4 3.  4.8]
#  [0.2 1.6 3.8 5.1]
#  [0.2 1.4 3.2 4.6]]

# %% [markdown]
# ###5 Buatlah scatter plot yang menggunakan pasangan attribut berikut pada setiap kelas (termasuk unknown). Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica, dan kuning untuk unknown
#
# Hint : gunakan perintah scatter dan operasi slicing pada numpy untuk mempermudah tugas anda

# %% [markdown]
# a. Sepal length dan petal width

# %%
import matplotlib.pyplot as plt
import numpy as np

#font
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'grey','size':15}
#judul, keterangan
plt.title("Scatter Plot Sepal length dan petal width", fontdict = font1)
plt.xlabel("Sepal length", fontdict = font2)
plt.ylabel("petal width", fontdict = font2)

#scatter plot : x = Sepal length, y = petal width
#plot setosa
plt.scatter(setosa[:,3], setosa[:,0], color = 'red')
#plot versicolor
plt.scatter(versicolor[:,3], versicolor[:,0], color = 'green')
#plot virginica
plt.scatter(virginica[:,3], virginica[:,0], color = 'blue')
#plot unknown
plt.scatter(unknown[:,3], unknown[:,0], color = 'yellow')

plt.show()

# %% [markdown]
# b. Sepal width petal length

# %%
import matplotlib.pyplot as plt
import numpy as np

#font
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'grey','size':15}
#judul, keterangan
plt.title("Scatter Plot Sepal width petal length", fontdict = font1)
plt.xlabel("Sepal width", fontdict = font2)
plt.ylabel("Petal length", fontdict = font2)

#scatter plot - x = Sepal width, y = petal length
#plot setosa
plt.scatter(setosa[:,2], setosa[:,1], color = 'red')
#plot versicolor
plt.scatter(versicolor[:,2], versicolor[:,1], color = 'green')
#plot virginica
plt.scatter(virginica[:,2], virginica[:,1], color = 'blue')
#plot unknown
plt.scatter(unknown[:,2], unknown[:,1], color = 'yellow')

plt.show()

# %% [markdown]
# c. Sepal width dan petal width

# %%
import matplotlib.pyplot as plt
import numpy as np

#font
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'grey','size':15}
#judul, keterangan
plt.title("Scatter Plot Sepal width dan petal width", fontdict = font1)
plt.xlabel("Sepal width", fontdict = font2)
plt.ylabel("Petal length", fontdict = font2)

#scatter plot - x = Sepal width, y = petal width
#plot setosa
plt.scatter(setosa[:,2], setosa[:,0], color = 'red')
#plot versicolor
plt.scatter(versicolor[:,2], versicolor[:,0], color = 'green')
#plot virginica
plt.scatter(virginica[:,2], virginica[:,0], color = 'blue')
#plot unknown
plt.scatter(unknown[:,2], unknown[:,0], color = 'yellow')

plt.show()

# %% [markdown]
# d. Seal length dan petal length

# %%
import matplotlib.pyplot as plt
import numpy as np

#font
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'grey','size':15}
#judul, keterangan
plt.title("Scatter Plot Sepal length dan petal length", fontdict = font1)
plt.xlabel("Sepal length", fontdict = font2)
plt.ylabel("Petal length", fontdict = font2)

#scatter plot - x = Sepal length, y = petal length
#plot setosa
plt.scatter(setosa[:,3], setosa[:,1], color = 'red')
#plot versicolor
plt.scatter(versicolor[:,3], versicolor[:,1], color = 'green')
#plot virginica
plt.scatter(virginica[:,3], virginica[:,1], color = 'blue')
#plot unknown
plt.scatter(unknown[:,3], unknown[:,1], color = 'yellow')

plt.show()

# %% [markdown]
# ###6 Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot

# %% [markdown]
# ###7 Perhatikan data yang berjenis unknown. Jelaskan bagaimana cara meramal jenis data unknown

# %% [markdown]
# ###8 Buatlah pararrel coordinat plot dari data yang berkelas setosa, versicolor, dan virginica. Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica. Hint gunakan perintah plot dan operasi slicing pada numpy untuk mempermudah tugas anda

# %%
import matplotlib.pyplot as plt
import numpy as np

#font
font1 = {'family':'serif','color':'black','size':20}
#judul, keterangan
plt.title("pararrel coordinat plot", fontdict = font1)

# setosa
for isibaris in setosa:
  y = np.array(isibaris)
  x = np.array(['Petal_width','Petal_length','Sepal_width','Sepal_length'])
  plt.plot(x, y, color = 'red')
#Versicolor
for isibaris in versicolor:
  y = np.array(isibaris)
  x = np.array(['Petal_width','Petal_length','Sepal_width','Sepal_length'])
  plt.plot(x, y, color = 'green')
#Verginica
for isibaris in virginica:
  y = np.array(isibaris)
  x = np.array(['Petal_width','Petal_length','Sepal_width','Sepal_length'])
  plt.plot(x, y, color = 'blue')

plt.show()

# %% [markdown]
# ###9 Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot
